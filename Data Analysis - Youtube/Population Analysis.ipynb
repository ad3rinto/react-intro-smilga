# %%
import pandas as pd
import numpy as np
import os

# %%
df_raw = pd.read_csv("population_total.csv")

# %%
df_raw.head()
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09

# %%
df = df_raw.dropna()

# %%
df
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %%
new_df
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
new_df.head()
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
#
# country     Angola  Anguilla  Antigua and Barbuda   Argentina    Armenia  ...  \
# year                                                                      ...
# 1955.0   5043247.0    5783.0              49648.0  18789418.0  1563507.0  ...
# 1960.0   5454933.0    6032.0              54131.0  20481779.0  1874121.0  ...
# 1965.0   5770570.0    6361.0              58698.0  22159650.0  2211319.0  ...
# 1970.0   5890365.0    6771.0              64177.0  23880561.0  2525068.0  ...
# ...

# %%
students_df = pd.read_csv("StudentsPerformance.csv")

# %%
students_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_df["Average Score"] = (students_df['math score'] + students_df['writing score'] + students_df['reading score'])/3

# %%
students_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
st_df = students_df[["gender", "parental level of education", "Average Score"]]

# %%
st_df
# Out:
#      gender parental level of education  Average Score
# 0    female           bachelor's degree      72.666667
# 1    female                some college      82.333333
# 2    female             master's degree      92.666667
# 3      male          associate's degree      49.333333
# 4      male                some college      76.333333
# ..      ...                         ...            ...
# 995  female             master's degree      94.000000
# 996    male                 high school      57.333333
# 997  female                 high school      65.000000
# 998  female                some college      74.333333
# 999  female                some college      83.000000
#
# [1000 rows x 3 columns]

# %%
sm_df = pd.read_csv("supermarket_sales - Sheet1.csv")

# %% [markdown]
# sm_df

# %%
sm_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sm_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sm_df.pivot_table(index="Gender", aggfunc="sum")
# Out:
# C:\Users\a127014\AppData\Local\Temp\ipykernel_12844\4091188263.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   sm_df.pivot_table(index="Gender", aggfunc="sum")
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
sm_df.pivot_table(index="Gender",
                  values=["Quantity", "Total", "gross income"],
                  aggfunc="mean")
# Out:
#         Quantity       Total  gross income
# Gender
# Female  5.726547  335.095659     15.956936
# Male    5.292585  310.789226     14.799487

# %%
sm_df.pivot_table(index="Gender",
                  values=["Quantity", "Total", "gross income"],
                  aggfunc="sum")
# Out:
#         Quantity       Total  gross income
# Gender
# Female      2869  167882.925      7994.425
# Male        2641  155083.824      7384.944

# %%
sm_df.pivot_table(index="Gender",
                  columns="Product line",
                  values="Total",
                  aggfunc="sum")
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                    27102.0225            30437.400          33170.9175
# Male                      27235.5090            23868.495          22973.9265
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female               18560.9865          30036.8775         28574.7210
# Male                 30632.7525          23825.0355         26548.1055

# %%
sm_df.pivot_table(index="Gender",
                  columns="Customer type",
                  values="Total",
                  aggfunc="sum")
# Out:
# Customer type      Member      Normal
# Gender
# Female         88146.9435  79735.9815
# Male           76076.5005  79007.3235

# %%
pop_df = new_df.dropna()

# %%
pop_df
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
df_pivot = pop_df[["United States", "Brazil","South Africa", "India", "Ghana", "China", "United Kingdom", "Nigeria"]]

# %%
df_pivot
# Out:
# country  United States       Brazil  South Africa         India       Ghana  \
# year
# 1955.0     171685336.0   62533919.0    15206502.0  4.098806e+08   5730594.0
# 1960.0     186720571.0   72179226.0    17099840.0  4.505477e+08   6635230.0
# 1965.0     199733676.0   83373530.0    19384841.0  4.991233e+08   7739473.0
# 1970.0     209513341.0   95113265.0    22069776.0  5.551898e+08   8735495.0
# 1975.0     219081251.0  107216205.0    25195187.0  6.231029e+08   9985946.0
# 1980.0     229476354.0  120694009.0    28556769.0  6.989528e+08  11056116.0
# 1985.0     240499825.0  135274080.0    32678874.0  7.843600e+08  12783613.0
# 1990.0     252120309.0  149003223.0    36800509.0  8.732778e+08  14773277.0
# 1995.0     265163745.0  162019896.0    41435758.0  9.639226e+08  17014057.0
# 2000.0     281710909.0  174790340.0    44967708.0  1.056576e+09  19278856.0
# 2005.0     294993511.0  186127103.0    47880601.0  1.147610e+09  21814642.0
# ...

# %% [markdown]
# # Line Plot

# %%
df_pivot.plot(kind="line", xlabel="Year", ylabel="In Billions", 
              figsize=(8, 4),
              title="Population (1955 - 2020)")
# Out:
# <Axes: title={'center': 'Population (1955 - 2020)'}, xlabel='Year', ylabel='In Billions'>

# %%
df_year = df_pivot[df_pivot.index.isin([2019])]

# %%
df_year
# Out:
# country  United States       Brazil  South Africa         India       Ghana  \
# year
# 2019.0     329064917.0  211049527.0    58558270.0  1.366418e+09  30417856.0
#
# country         China  United Kingdom      Nigeria
# year
# 2019.0   1.433784e+09      67530172.0  200963599.0

# %%
df_year.plot(kind="bar", figsize=(8,4), ylabel="In billions")
# Out:
# <Axes: xlabel='year', ylabel='In billions'>

# %%
df_year = df_year.T
# Out:
# year                  2019.0
# country
# United States   3.290649e+08
# Brazil          2.110495e+08
# South Africa    5.855827e+07
# India           1.366418e+09
# Ghana           3.041786e+07
# China           1.433784e+09
# United Kingdom  6.753017e+07
# Nigeria         2.009636e+08

# %%
df_year.plot(kind="bar", figsize=(8,4), xlabel="country", ylabel="In billions")
# Out:
# <Axes: xlabel='country', ylabel='In billions'>

# %%
df_group_of_years = df_pivot[df_pivot.index.isin([1980, 1988, 1990, 2000,2010, 2019])]

# %%
df_group_of_years
# Out:
# country  United States       Brazil  South Africa         India       Ghana  \
# year
# 1980.0     229476354.0  120694009.0    28556769.0  6.989528e+08  11056116.0
# 1990.0     252120309.0  149003223.0    36800509.0  8.732778e+08  14773277.0
# 2000.0     281710909.0  174790340.0    44967708.0  1.056576e+09  19278856.0
# 2010.0     309011475.0  195713635.0    51216964.0  1.234281e+09  24779619.0
# 2019.0     329064917.0  211049527.0    58558270.0  1.366418e+09  30417856.0
#
# country         China  United Kingdom      Nigeria
# year
# 1980.0   1.000089e+09      56209171.0   73423633.0
# 1990.0   1.176884e+09      57134391.0   95212450.0
# 2000.0   1.290551e+09      58923309.0  122283850.0
# 2010.0   1.368811e+09      63459808.0  158503197.0
# 2019.0   1.433784e+09      67530172.0  200963599.0

# %%
df_group_of_years.plot(kind="bar", figsize=(8,4))
# Out:
# <Axes: xlabel='year'>

# %%
df_year = df_year.T

# %%
df_yea
# Out:
# year                  2019.0
# country
# United States   3.290649e+08
# Brazil          2.110495e+08
# South Africa    5.855827e+07
# India           1.366418e+09
# Ghana           3.041786e+07
# China           1.433784e+09
# United Kingdom  6.753017e+07
# Nigeria         2.009636e+08

# %%
df_year.rename(columns={2019.0:"2019"}, inplace=True)

# %%
df_year
# Out:
# year                    2019
# country
# United States   3.290649e+08
# Brazil          2.110495e+08
# South Africa    5.855827e+07
# India           1.366418e+09
# Ghana           3.041786e+07
# China           1.433784e+09
# United Kingdom  6.753017e+07
# Nigeria         2.009636e+08

# %%
df_year.plot(kind="pie", y="2019")
plt.savefig("my_test.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df_pivot.to_excel("pivot_table.xlsx")
